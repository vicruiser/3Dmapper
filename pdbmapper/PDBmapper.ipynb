# %%
####################### VARIANTS PART #####################################################

# %%
import pandas as pd
import glob
from scripts.explode import explode
import sys
import os
import re   

import pandas as pd
import numpy as np

import csv

# %%
maf = "/home/vruizser/head_mc3.maf"
maf = '/home/vruizser/PhD/2018-2019/Immunity_interfaces_analysis/raw_data/mc3.v0.2.8.PUBLIC.maf'

up_cols=["Chromosome", "Start_Position", "Reference_Allele", "Allele"]
loc_cols = ["Chromosome", "Start_Position", "End_Position"]
rest_of_cols = ["Allele",
                "Gene",
                "Feature",
                "Feature_type",
                "Consequence",
                "cDNA_position",
                "CDS_position",
                "Protein_position",
                "Amino_acids",
                "Codons",
                "Existing_variation"]

with open(maf) as f:
    # get col names
    cols = f.readline().split('\t')
    uploaded_variation_cols=np.where(np.isin(cols,up_cols))
    location_cols = np.where(np.isin(cols,up_cols))
    rest_cols=np.where(np.isin(cols, rest_of_cols))
    #print('Uploaded_variation', ' '.join(rest_of_cols) + '\n')
    #updated_colnames = 'Uploaded_variation' + '\t' + '\t'.join(rest_of_cols)
    updated_colnames = ['Uploaded_variation'] + rest_of_cols
    #fff = open('cool_file.vep', 'wb')
    with open('mc3_all_transformed.csv', 'w', newline='', encoding='utf8') as csvfile:
        writer = csv.writer(csvfile, delimiter='\t')
        #fff.write( updated_colnames)
        #fff.write('\n')
        writer.writerow(updated_colnames)
          # parse file
        for line in f:
            #print(line.split('\t')[N[0][0]] + '_' + line.split('\t')[N[0][0]])
            all_s = np.asarray(line.split('\t'))[uploaded_variation_cols]
            rest_s = np.asarray(line.split('\t'))[rest_cols]
            
            to_save = '_'.join(all_s[:-1]) + '/' + all_s[-1], ' '.join(rest_s) + '\n'
            to_save = ['_'.join(all_s[:-1]) + '/' + all_s[-1]] + rest_s.tolist()

            writer.writerow(to_save)
            #fff.write( str('\t'.join(to_save)))
            #fff.write('\n')
            # save up to a file write and the close it
            #print(pd.DataFrame(list(line)))


#'awk 'NR==1 { \
#    for (i=1; i<=NF; i++) { \
#        f[$i] = i \
#    } \
#    } \
#{ print $(f["Consequence"])"_"$(f["Start_Position"]) } \
#' head_mc3.maf '

#detect_column = "awk -F ' ' '{{for(i=1;i<=NF;i++) {{if ($i ~ /{}/){{print i; exit}}}}}}' {}"

#print(detect_colum)
